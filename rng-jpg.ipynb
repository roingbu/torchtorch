# %%
from PIL import Image
import os
img = Image.open('labels/1.jpg')
print(img.mode)
# Out:
# L

# %%
# 批量tiff转jpg
# 代码中路径更改为自己图像存放路径即可
from PIL import Image
import os
 
imagesDirectory = "gt"  # tiff图片所在文件夹路径
distDirectory = "pngImages"# 要存放jpg格式的文件夹路径
for imageName in os.listdir(imagesDirectory):
    imagePath = os.path.join(imagesDirectory, imageName)
    image = Image.open(imagePath)# 打开tiff图像
    distImagePath = os.path.join(distDirectory, imageName[:-5]+'.png')# 更改图像后缀为.jpg，并保证与原图像同名
    print(imagePath)
    image.save(distImagePath)# 保存jpg图像
# Out:
# gt\austin1.tif
# gt\austin11.tif
# gt\austin12.tif
# gt\austin13.tif
# gt\austin14.tif
# gt\austin15.tif
# gt\austin17.tif
# gt\austin18.tif
# gt\austin19.tif
# gt\austin2.tif
# gt\austin20.tif
# gt\austin22.tif
# gt\austin23.tif
# gt\austin24.tif
# gt\austin26.tif
# gt\austin28.tif
# gt\austin29.tif
# gt\austin3.tif
# gt\austin30.tif
# gt\austin34.tif
# gt\austin35.tif
# gt\austin36.tif
# gt\austin7.tif
# gt\austin8.tif
# gt\austin9.tif
# gt\chicago10.tif
# gt\chicago11.tif
# gt\chicago12.tif
# gt\chicago13.tif
# gt\chicago15.tif
# gt\chicago16.tif
# gt\chicago17.tif
# gt\chicago18.tif
# gt\chicago19.tif
# gt\chicago2.tif
# gt\chicago21.tif
# gt\chicago22.tif
# gt\chicago23.tif
# gt\chicago24.tif
# gt\chicago3.tif
# gt\chicago4.tif
# gt\chicago6.tif
# gt\chicago7.tif
# gt\chicago8.tif
# gt\chicago9.tif

# %%
import os
from PIL import Image

original_path = u'gt_png'
saved_path = u'gt_jpg'

counts = 0
files = os.listdir(original_path)
for file in files:
    if file.endswith('jpg'):
        tif_file = os.path.join(original_path, file)

        file = file[:-3] + 'jpg'
        png_file = os.path.join(saved_path, file)
        img = Image.open(tif_file)
        img_array = np.array(img)
        img = Image.fromarray(np.uint8(img_array))
        img.save(png_file)
        print(png_file)
        counts += 1

print('%d done' %counts)
# Out:
# gt_jpg\austin1.jpg
# gt_jpg\austin11.jpg
# gt_jpg\austin12.jpg
# gt_jpg\austin13.jpg
# gt_jpg\austin14.jpg
# gt_jpg\austin15.jpg
# gt_jpg\austin17.jpg
# gt_jpg\austin18.jpg
# gt_jpg\austin19.jpg
# gt_jpg\austin2.jpg
# gt_jpg\austin20.jpg
# gt_jpg\austin22.jpg
# gt_jpg\austin23.jpg
# gt_jpg\austin24.jpg
# gt_jpg\austin26.jpg
# gt_jpg\austin28.jpg
# gt_jpg\austin29.jpg
# gt_jpg\austin3.jpg
# gt_jpg\austin30.jpg
# gt_jpg\austin34.jpg
# gt_jpg\austin35.jpg
# gt_jpg\austin36.jpg
# gt_jpg\austin7.jpg
# gt_jpg\austin8.jpg
# gt_jpg\austin9.jpg
# 25 done

# %%
import os
from PIL import Image

original_path = u'labels'
saved_path = u'gt_p'

counts = 0
files = os.listdir(original_path)
for file in files:
    if file.endswith('jpg'):
        tif_file = os.path.join(original_path, file)

        file = file[:-3] + 'png'
        png_file = os.path.join(saved_path, file)
        im = Image.open(tif_file)
        im_P = im.convert("P")
        im_P.save(png_file)
        print(png_file)
        counts += 1

print('%d done' %counts)
# Out:
# gt_p\0.png
# gt_p\1.png
# gt_p\10.png
# gt_p\100.png
# gt_p\1000.png
# gt_p\1001.png
# gt_p\1002.png
# gt_p\1003.png
# gt_p\1004.png
# gt_p\1005.png
# gt_p\1006.png
# gt_p\1007.png
# gt_p\1008.png
# gt_p\1009.png
# gt_p\101.png
# gt_p\1010.png
# gt_p\1011.png
# gt_p\1012.png
# gt_p\1013.png
# gt_p\1014.png
# gt_p\1015.png
# gt_p\1016.png
# gt_p\1017.png
# gt_p\1018.png
# gt_p\1019.png
# gt_p\102.png
# gt_p\1020.png
# gt_p\1021.png
# gt_p\1022.png
# gt_p\1023.png
# gt_p\1024.png
# gt_p\1025.png
# gt_p\1026.png
# gt_p\1027.png
# gt_p\1028.png
# gt_p\1029.png
# gt_p\103.png
# gt_p\1030.png
# gt_p\1031.png
# gt_p\1032.png
# gt_p\1033.png
# gt_p\1034.png
# gt_p\1035.png
# gt_p\1036.png
# gt_p\1037.png
# gt_p\1038.png
# gt_p\1039.png
# gt_p\104.png
# gt_p\1040.png
# gt_p\1041.png
# gt_p\1042.png
# gt_p\1043.png
# gt_p\1044.png
# gt_p\1045.png
# gt_p\1046.png
# gt_p\1047.png
# gt_p\1048.png
# gt_p\1049.png
# gt_p\105.png
# gt_p\1050.png
# gt_p\1051.png
# gt_p\1052.png
# gt_p\1053.png
# ...
